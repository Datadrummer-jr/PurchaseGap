# %% [markdown]
#                                 DATAPYME

# %%
from IPython.display import Image
Image(filename="images/logo.png")

# %% [markdown]
# Datapyme es un proyecto de ciencia de datos que busca iluminar el complejo panorama económico de la Cuba contemporánea a través de la programación y el análisis de datos. Su objetivo principal es examinar cómo las fluctuaciones del dólar estadounidense y de otras divisas extranjeras influyen en las estrategias de precios de las MIPYMES (micro, pequeñas y medianas empresas) y de las tiendas en MLC (moneda libremente convertible). Al comparar de manera sistemática la dinámica de los precios locales con referentes globales, el proyecto revela patrones de inflación, procesos de adaptación empresarial y cambios estratégicos en la accesibilidad del consumidor.
#
# Más allá del dólar, Datapyme amplía su alcance para analizar el comportamiento general de las divisas extranjeras en Cuba, explorando cómo interactúan con las estructuras económicas locales y cómo impactan en las transacciones cotidianas. Este enfoque multidimensional permite comprender con mayor profundidad la búsqueda de autonomía económica, la resiliencia de las empresas y los retos que imponen las presiones del mercado global.
#
# En última instancia, Datapyme no es solo un ejercicio técnico de programación y ciencia de datos, sino también una exploración estratégica de cómo los conocimientos basados en datos pueden revelar los mecanismos ocultos de la supervivencia, la adaptación y la independencia económica. Su propósito es aportar un recurso valioso para estudiantes, investigadores y emprendedores interesados en la intersección entre tecnología, economía y transformación social.

# %% [markdown]
# Instalación dependencias de python necesarias :

# %%
import importlib.util
import subprocess
import sys

subprocess.run([sys.executable, "-m", "pip", "install", "-r", "requirements.txt"])

spec = importlib.util.spec_from_file_location("code", "code.py")
code = importlib.util.module_from_spec(spec)
spec.loader.exec_module(code)

# %% [markdown]
# ! EN el archivo json de origen del listado de los actores económicos hay error en el pdf en número 6778, pusieron 6678

# %%
print(sum(code.bar_pymes()))
# Out:
# 11288

# %%
import numpy as np
import matplotlib.pyplot as plt

nivel1 = np.arange(10) * 100 + 5
nivel2 = np.arange(10) * 300 + 15
eje_x = np.arange(10)

fig, ax = plt.subplots()

ax.bar(eje_x, nivel2, label='Serie 1')
ax.bar(eje_x, nivel1 , bottom= nivel2, label='Serie 2')
ax.legend()
plt.show()

# %%
code.graph_coin()

# %%
import folium as fl

def map():
    m = fl.Map()
    return m

map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa3fc6080a1d7e2cea60a41c91e222d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa3fc6080a1d7e2cea60a41c91e222d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa3fc6080a1d7e2cea60a41c91e222d0 = L.map(
#                 &quot;map_aa3fc6080a1d7e2cea60a41c91e222d0&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65efed0945625b6032d36aabddc4bb58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65efed0945625b6032d36aabddc4bb58.addTo(map_aa3fc6080a1d7e2cea60a41c91e222d0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
