# %% [markdown]
#                                                        DATAPYME

# %% [markdown]
# Datapyme es un proyecto de ciencia de datos que analiza el impacto del dólar en los precios de las tiendas MIPYMES y MLC en Cuba. Compara la dinámica de precios locales con referencias globales, explorando la autonomía económica, los patrones de inflación y los cambios estratégicos de precios en Cuba.

# %% [markdown]
# Instalación de los paquetes necesarios

# %%
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: httpx in d:\data science\programación\datapyme\.venv\lib\site-packages (from -r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: telethon in d:\data science\programación\datapyme\.venv\lib\site-packages (from -r requirements.txt (line 2)) (1.42.0)
# Requirement already satisfied: python_dotenv in d:\data science\programación\datapyme\.venv\lib\site-packages (from -r requirements.txt (line 3)) (1.2.1)
# Requirement already satisfied: matplotlib in d:\data science\programación\datapyme\.venv\lib\site-packages (from -r requirements.txt (line 4)) (3.10.7)
# Requirement already satisfied: plotly in d:\data science\programación\datapyme\.venv\lib\site-packages (from -r requirements.txt (line 5)) (6.5.0)
# Requirement already satisfied: bokeh in d:\data science\programación\datapyme\.venv\lib\site-packages (from -r requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: cython in d:\data science\programación\datapyme\.venv\lib\site-packages (from -r requirements.txt (line 7)) (3.2.1)
# Requirement already satisfied: setuptools in d:\data science\programación\datapyme\.venv\lib\site-packages (from -r requirements.txt (line 8)) (80.9.0)
# Requirement already satisfied: openpyxl in d:\data science\programación\datapyme\.venv\lib\site-packages (from -r requirements.txt (line 9)) (3.1.5)
# Collecting xlrd==1.2.0 (from -r requirements.txt (line 10))
#   Downloading xlrd-1.2.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: anyio in d:\data science\programación\datapyme\.venv\lib\site-packages (from httpx->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: certifi in d:\data science\programación\datapyme\.venv\lib\site-packages (from httpx->-r requirements.txt (line 1)) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in d:\data science\programación\datapyme\.venv\lib\site-packages (from httpx->-r requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: idna in d:\data science\programación\datapyme\.venv\lib\site-packages (from httpx->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: h11>=0.16 in d:\data science\programación\datapyme\.venv\lib\site-packages (from httpcore==1.*->httpx->-r requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: pyaes in d:\data science\programación\datapyme\.venv\lib\site-packages (from telethon->-r requirements.txt (line 2)) (1.6.1)
# Requirement already satisfied: rsa in d:\data science\programación\datapyme\.venv\lib\site-packages (from telethon->-r requirements.txt (line 2)) (4.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\data science\programación\datapyme\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\data science\programación\datapyme\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\data science\programación\datapyme\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\data science\programación\datapyme\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in d:\data science\programación\datapyme\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in d:\data science\programación\datapyme\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in d:\data science\programación\datapyme\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in d:\data science\programación\datapyme\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\data science\programación\datapyme\.venv\lib\site-packages (from matplotlib->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in d:\data science\programación\datapyme\.venv\lib\site-packages (from plotly->-r requirements.txt (line 5)) (2.11.0)
# Requirement already satisfied: Jinja2>=2.9 in d:\data science\programación\datapyme\.venv\lib\site-packages (from bokeh->-r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: pandas>=1.2 in d:\data science\programación\datapyme\.venv\lib\site-packages (from bokeh->-r requirements.txt (line 6)) (2.3.3)
# Requirement already satisfied: PyYAML>=3.10 in d:\data science\programación\datapyme\.venv\lib\site-packages (from bokeh->-r requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in d:\data science\programación\datapyme\.venv\lib\site-packages (from bokeh->-r requirements.txt (line 6)) (6.5.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in d:\data science\programación\datapyme\.venv\lib\site-packages (from bokeh->-r requirements.txt (line 6)) (2025.10.0)
# Requirement already satisfied: et-xmlfile in d:\data science\programación\datapyme\.venv\lib\site-packages (from openpyxl->-r requirements.txt (line 9)) (2.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\data science\programación\datapyme\.venv\lib\site-packages (from Jinja2>=2.9->bokeh->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in d:\data science\programación\datapyme\.venv\lib\site-packages (from pandas>=1.2->bokeh->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\data science\programación\datapyme\.venv\lib\site-packages (from pandas>=1.2->bokeh->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\data science\programación\datapyme\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in d:\data science\programación\datapyme\.venv\lib\site-packages (from anyio->httpx->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: pyasn1>=0.1.3 in d:\data science\programación\datapyme\.venv\lib\site-packages (from rsa->telethon->-r requirements.txt (line 2)) (0.6.1)
# Downloading xlrd-1.2.0-py2.py3-none-any.whl (103 kB)
# Installing collected packages: xlrd
# Successfully installed xlrd-1.2.0

# %%
! pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.11.0
# anywidget                 0.9.21
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.0.5
# attrs                     25.4.0
# babel                     2.17.0
# beautifulsoup4            4.14.2
# bleach                    6.3.0
# bokeh                     3.8.1
# certifi                   2025.11.12
# cffi                      2.0.0
# charset-normalizer        3.4.4
# colorama                  0.4.6
# comm                      0.2.3
# contourpy                 1.3.3
# cycler                    0.12.1
# Cython                    3.2.1
# debugpy                   1.8.17
# decorator                 5.2.1
# defusedxml                0.7.1
# et_xmlfile                2.0.0
# executing                 2.2.1
# fastjsonschema            2.21.2
# fonttools                 4.60.1
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.11
# ipykernel                 7.1.0
# ipython                   9.7.0
# ipython_pygments_lexers   1.1.1
# ipywidgets                8.1.8
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# json5                     0.12.1
# jsonpointer               3.0.0
# jsonschema                4.25.1
# jsonschema-specifications 2025.9.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.9.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.4.10
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# jupyterlab_widgets        3.0.16
# kiwisolver                1.4.9
# lark                      1.3.1
# MarkupSafe                3.0.3
# matplotlib                3.10.7
# matplotlib-inline         0.2.1
# mistune                   3.1.4
# narwhals                  2.11.0
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.4.7
# notebook_shim             0.2.4
# numpy                     2.3.5
# openpyxl                  3.1.5
# packaging                 25.0
# pandas                    2.3.3
# pandocfilters             1.5.1
# parso                     0.8.5
# pillow                    12.0.0
# pip                       25.3
# platformdirs              4.5.0
# plotly                    6.5.0
# plotly-geo                1.0.0
# prometheus_client         0.23.1
# prompt_toolkit            3.0.52
# psutil                    7.1.3
# psygnal                   0.15.0
# pure_eval                 0.2.3
# pyaes                     1.6.1
# pyasn1                    0.6.1
# pycparser                 2.23
# Pygments                  2.19.2
# pyparsing                 3.2.5
# python-dateutil           2.9.0.post0
# python-dotenv             1.2.1
# python-json-logger        4.0.0
# pytz                      2025.2
# pywinpty                  3.0.2
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.37.0
# requests                  2.32.5
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.29.0
# rsa                       4.9.1
# Send2Trash                1.8.3
# setuptools                80.9.0
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.8
# stack-data                0.6.3
# Telethon                  1.42.0
# terminado                 0.18.1
# tinycss2                  1.4.0
# tornado                   6.5.2
# traitlets                 5.14.3
# typing_extensions         4.15.0
# tzdata                    2025.2
# uri-template              1.3.0
# urllib3                   2.5.0
# wcwidth                   0.2.14
# webcolors                 25.10.0
# webencodings              0.5.1
# websocket-client          1.9.0
# widgetsnbextension        4.0.15
# xyzservices               2025.10.0

# %%
import importlib.util

spec = importlib.util.spec_from_file_location("code", "code.py")
code = importlib.util.module_from_spec(spec)
spec.loader.exec_module(code)

# %%
code.salary()
# Out:
# 0 | 44 horas: 2100 | 40 horas : 1910
# 1 | 44 horas: 2200 | 40 horas : 2000
# 2 | 44 horas: 2300 | 40 horas : 2090
# 3 | 44 horas: 2420 | 40 horas : 2200
# 4 | 44 horas: 2540 | 40 horas : 2310
# 5 | 44 horas: 2660 | 40 horas : 2415
# 6 | 44 horas: 2810 | 40 horas : 2555
# 7 | 44 horas: 2960 | 40 horas : 2690
# 8 | 44 horas: 3110 | 40 horas : 2825
# 9 | 44 horas: 3260 | 40 horas : 2965
# 10 | 44 horas: 3410 | 40 horas : 3100
# 11 | 44 horas: 3610 | 40 horas : 3280
# 12 | 44 horas: 3810 | 40 horas : 3465
# 13 | 44 horas: 4010 | 40 horas : 3645
# 14 | 44 horas: 4210 | 40 horas : 3825
# 15 | 44 horas: 4410 | 40 horas : 4010
# 16 | 44 horas: 4610 | 40 horas : 4190
# 17 | 44 horas: 4810 | 40 horas : 4375
# 18 | 44 horas: 5060 | 40 horas : 4600
# 19 | 44 horas: 5310 | 40 horas : 4825
# 20 | 44 horas: 5510 | 40 horas : 5055
# 21 | 44 horas: 5810 | 40 horas : 5285
# 22 | 44 horas: 6060 | 40 horas : 5510
# 23 | 44 horas: 6310 | 40 horas : 5735
# 24 | 44 horas: 6610 | 40 horas : 6010
# 25 | 44 horas: 6910 | 40 horas : 6325
# 26 | 44 horas: 7310 | 40 horas : 6645
# 27 | 44 horas: 7660 | 40 horas : 6965
# 28 | 44 horas: 8010 | 40 horas : 7285
# 29 | 44 horas: 8510 | 40 horas : 7735
# 30 | 44 horas: 9010 | 40 horas : 8190
# 31 | 44 horas: 9510 | 40 horas : 8645
